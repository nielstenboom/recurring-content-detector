# %%
! pip install tqdm
! pip install opencv-python
! pip install boto3
! pip install scipy
# Out:
# Collecting tqdm
#   Using cached https://files.pythonhosted.org/packages/45/af/685bf3ce889ea191f3b916557f5677cc95a5e87b2fa120d74b5dd6d049d0/tqdm-4.32.1-py2.py3-none-any.whl
# Installing collected packages: tqdm
# Successfully installed tqdm-4.32.1
# You are using pip version 9.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting opencv-python
#   Using cached https://files.pythonhosted.org/packages/7b/d2/a2dbf83d4553ca6b3701d91d75e42fe50aea97acdc00652dca515749fb5d/opencv_python-4.1.0.25-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: numpy>=1.11.3 in /mnt/anaconda2/envs/py36/lib/python3.6/site-packages (from opencv-python)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.1.0.25
# You are using pip version 9.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting boto3
#   Using cached https://files.pythonhosted.org/packages/f9/e5/5c138b6876b095765edacdcf4487fecd3fecb218ed08f64e65671db0d370/boto3-1.9.156-py2.py3-none-any.whl
# Collecting botocore<1.13.0,>=1.12.156 (from boto3)
#   Using cached https://files.pythonhosted.org/packages/f5/aa/79fc47ccc3c7d0f36aafb9d85091d7d8a8f10d8ad24ccf3a89cf126b9f4e/botocore-1.12.156-py2.py3-none-any.whl
# Collecting s3transfer<0.3.0,>=0.2.0 (from boto3)
#   Using cached https://files.pythonhosted.org/packages/d7/de/5737f602e22073ecbded7a0c590707085e154e32b68d86545dcc31004c02/s3transfer-0.2.0-py2.py3-none-any.whl
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3)
#   Using cached https://files.pythonhosted.org/packages/83/94/7179c3832a6d45b266ddb2aac329e101367fbdb11f425f13771d27f225bb/jmespath-0.9.4-py2.py3-none-any.whl
# Collecting urllib3<1.26,>=1.20; python_version >= "3.4" (from botocore<1.13.0,>=1.12.156->boto3)
#   Using cached https://files.pythonhosted.org/packages/e6/60/247f23a7121ae632d62811ba7f273d0e58972d75e58a94d329d51550a47d/urllib3-1.25.3-py2.py3-none-any.whl
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /mnt/anaconda2/envs/py36/lib/python3.6/site-packages (from botocore<1.13.0,>=1.12.156->boto3)
# Requirement already satisfied: docutils>=0.10 in /mnt/anaconda2/envs/py36/lib/python3.6/site-packages (from botocore<1.13.0,>=1.12.156->boto3)
# Requirement already satisfied: six>=1.5 in /mnt/anaconda2/envs/py36/lib/python3.6/site-packages (from python-dateutil<3.0.0,>=2.1; python_version >= "2.7"->botocore<1.13.0,>=1.12.156->boto3)
# Installing collected packages: jmespath, urllib3, botocore, s3transfer, boto3
# Successfully installed boto3-1.9.156 botocore-1.12.156 jmespath-0.9.4 s3transfer-0.2.0 urllib3-1.25.3
# You are using pip version 9.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: scipy in /mnt/anaconda2/envs/py36/lib/python3.6/site-packages
# You are using pip version 9.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import boto3
from boto3.s3.transfer import S3Transfer
from tqdm import tqdm_notebook as tqdm
import json
import os
from os.path import isfile, join
from os import listdir
from os.path import isfile, join
import numpy as np
import pickle
import faiss
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)
import pandas as pd
import traceback
import scipy.ndimage
import itertools, operator
import datetime
import math

# %%
files = [f for f in os.listdir('videos') if isfile(join('videos', f))]

shows = {}
for file in files:
    fullname = file.split('/')[-1]
    fn = fullname.replace('_VOD','').replace('_high','')
    fn_split = fn.split('_')
    
    name = "_".join(fn_split[1:-2])
    season = fn_split[-2]
    episode = fn_split[-1].split('.')[0]
    
#     print("name: {}, season: {}, episode: {}".format(name, season, episode))
    
    if name not in shows:
        shows[name] = {season : {episode : fullname}}
    
    if season not in shows[name]:
        shows[name][season] = {episode : fullname}
        
    if episode not in shows[name][season]:
        shows[name][season][episode] = fullname

    
print(json.dumps(shows, indent=2))
print("\n Total of {} files".format(len(files)))
# Out:
# {
#   "Divorce": {
#     "S3": {
#       "E1": "217394H1_Divorce_S3_E1.mxf.mp4",
#       "E3": "217396H1_Divorce_S3_E3.mxf.mp4",
#       "E2": "217395H1_Divorce_S3_E2.mxf.mp4"
#     },
#     "S2": {
#       "E2": "208888H1_Divorce_S2_E2.mxf.mp4",
#       "E3": "208889H1_Divorce_S2_E3.mxf.mp4",
#       "E1": "208887H1_Divorce_S2_E1.mxf.mp4"
#     },
#     "S1": {
#       "E1": "193757H1_Divorce_S1_E1.mxf.mp4",
#       "E3": "193917H1_Divorce_S1_E3.mxf.mp4",
#       "E2": "193916H1_Divorce_S1_E2.mxf.mp4"
#     }
#   },
#   "Expeditie_Robinson": {
#     "S11": {
#       "E2": "226558H1_Expeditie_Robinson_S11_E2.mxf.mp4",
#       "E3": "226559H1_Expeditie_Robinson_S11_E3.mxf.mp4",
#       "E1": "226557H1_Expeditie_Robinson_S11_E1.mxf.mp4"
#     },
#     "S13": {
#       "E1": "251218H1_Expeditie_Robinson_S13_E1.mxf.mp4",
#       "E2": "250463H1_Expeditie_Robinson_S13_E2.mxf.mp4"
#     },
#     "S14": {
#       "E3": "260888H1_Expeditie_Robinson_S14_E3.mxf.mp4",
#       "E1": "262135H1_Expeditie_Robinson_S14_E1.mxf.mp4",
#       "E2": "262136H1_Expeditie_Robinson_S14_E2.mxf.mp4"
#     },
#     "S10": {
#       "E3": "214790A1_Expeditie_Robinson_S10_E3.mxf.mp4",
#       "E2": "214789B1_Expeditie_Robinson_S10_E2.mxf.mp4",
#       "E1": "214579A1_Expeditie_Robinson_S10_E1.mxf.mp4"
#     }
#   },
#   "Temptation_Island": {
#     "S4": {
#       "E5": "265708H1_Temptation_Island_S4_E5_high.mp4",
#       "E3": "266844H1_Temptation_Island_S4_E3_high.mp4",
#       "E6": "265709H1_Temptation_Island_S4_E6_high.mp4",
#       "E2": "266843H1_Temptation_Island_S4_E2_high.mp4",
#       "E4": "265707H1_Temptation_Island_S4_E4_high.mp4",
#       "E8": "265711H1_Temptation_Island_S4_E8_high.mp4",
#       "E7": "265710H1_Temptation_Island_S4_E7_high.mp4",
#       "E1": "266841H1_Temptation_Island_S4_E1_high.mp4",
#       "E9": "265712H1_Temptation_Island_S4_E9_high.mp4"
#     }
#   },
#   "How_Its_Done": {
#     "S3": {
#       "E3": "266185H1_How_Its_Done_S3_E3_high.mp4",
#       "E5": "266187H1_How_Its_Done_S3_E5_high.mp4",
#       "E4": "266186H1_How_Its_Done_S3_E4_high.mp4",
#       "E6": "266188H1_How_Its_Done_S3_E6_high.mp4",
#       "E2": "266184H1_How_Its_Done_S3_E2_high.mp4",
#       "E1": "266537H1_How_Its_Done_S3_E1_high.mp4"
#     }
#   },
#   "Dexter": {
#     "S8": {
#       "E12": "000_Dexter_S8_E12.mkv",
#       "E3": "000_Dexter_S8_E3.mkv",
#       "E7": "000_Dexter_S8_E7.mkv",
#       "E5": "000_Dexter_S8_E5.mkv",
#       "E10": "000_Dexter_S8_E10.mkv",
#       "E1": "000_Dexter_S8_E1.mkv",
#       "E9": "000_Dexter_S8_E9.mkv",
#       "E4": "000_Dexter_S8_E4.mkv",
#       "E8": "000_Dexter_S8_E8.mkv",
#       "E6": "000_Dexter_S8_E6.mkv",
#       "E11": "000_Dexter_S8_E11.mkv",
#       "E2": "000_Dexter_S8_E2.mkv"
#     }
#   },
#   "Judas": {
#     "S1": {
#       "E5": "263781H1_Judas_S1_E5_high.mp4",
#       "E4": "263780H1_Judas_S1_E4_high.mp4",
#       "E6": "263782H1_Judas_S1_E6_high.mp4",
#       "E3": "263779H1_Judas_S1_E3_high.mp4",
#       "E1": "263777H1_Judas_S1_E1_high.mp4",
#       "E2": "263778H1_Judas_S1_E2_high.mp4"
#     }
#   },
#   "Familie_Kruys": {
#     "S1": {
#       "E2": "219120H1_Familie_Kruys_S1_E2_VOD.mxf.mp4",
#       "E3": "219121H1_Familie_Kruys_S1_E3_VOD.mxf.mp4",
#       "E1": "219119H1_Familie_Kruys_S1_E1_VOD.mxf.mp4"
#     },
#     "S4": {
#       "E2": "261246H1_Familie_Kruys_S4_E2.mxf.mp4",
#       "E1": "261245H1_Familie_Kruys_S4_E1.mxf.mp4",
#       "E3": "261247H1_Familie_Kruys_S4_E3.mxf.mp4"
#     }
#   },
#   "Raveleijn": {
#     "S1": {
#       "E11": "263279H1_Raveleijn_S1_E11_high.mp4",
#       "E10": "263278H1_Raveleijn_S1_E10_high.mp4",
#       "E1": "263269H1_Raveleijn_S1_E1_high.mp4",
#       "E9": "263277H1_Raveleijn_S1_E9_high.mp4",
#       "E5": "263273H1_Raveleijn_S1_E5_high.mp4",
#       "E12": "263280H1_Raveleijn_S1_E12_high.mp4",
#       "E3": "263271H1_Raveleijn_S1_E3_high.mp4",
#       "E7": "263275H1_Raveleijn_S1_E7_high.mp4",
#       "E2": "263270H1_Raveleijn_S1_E2_high.mp4",
#       "E6": "263274H1_Raveleijn_S1_E6_high.mp4",
#       "E4": "263272H1_Raveleijn_S1_E4_high.mp4",
#       "E8": "263276H1_Raveleijn_S1_E8_high.mp4"
#     }
#   },
#   "Het_Italiaanse_Dorp": {
#     "S1": {
#       "E2": "258520H1_Het_Italiaanse_Dorp_S1_E2.mxf.mp4",
#       "E1": "258519H1_Het_Italiaanse_Dorp_S1_E1.mxf.mp4"
#     }
#   },
#   "Meisje_Van_Plezier": {
#     "S1": {
#       "E2": "245406H1_Meisje_Van_Plezier_S1_E2.mxf.mp4",
#       "E3": "245407H1_Meisje_Van_Plezier_S1_E3.mxf.mp4",
#       "E1": "245405H1_Meisje_Van_Plezier_S1_E1.mxf.mp4"
#     }
#   },
#   "Herman_Tegen_De_Rest": {
#     "S1": {
#       "E3": "266162H1_Herman_Tegen_De_Rest_S1_E3_high.mp4",
#       "E1": "266160H1_Herman_Tegen_De_Rest_S1_E1_high.mp4",
#       "E4": "266163H1_Herman_Tegen_De_Rest_S1_E4_high.mp4",
#       "E2": "266161H1_Herman_Tegen_De_Rest_S1_E2_high.mp4"
#     }
#   }
# }
#
#  Total of 80 files

# %%
def merge_consecutive_timestamps(timestamps):
    """
    Merges consecutive timestamps in a list if they're less than 2 seconds apart
    Example: [(0,5), (5,10), (20,30)] gets combined into [(0,10),[20,30]
    """
    result = []
    i = 0
    while i < len(timestamps):
        (start, end) = timestamps[i]

        # check if we're not already at the last element
        if i < len(timestamps) - 1:
            (start_next, end_next) = timestamps[i + 1]
            # merge if less than 2 seconds apart
            if abs(end - start_next) < 2:
                result.append((start, end_next))
                i += 1
            else:
                result.append((start,end))
            
        else:
            result.append((start, end))

        i += 1

    return result

def to_seconds(time):
    """
    Converts string of format hh:mm:ss to total number of seconds
    """
    if time == 'None':
        return -1
    try:
        hours = int(time.split(":")[0])
        minutes = int(time.split(":")[1])
        seconds = int(float(time.split(":")[2]))
        return hours*60*60 + minutes * 60 + seconds
    except:
#         print(time)
        if math.isnan(time):
            return -1

def get_skippable_timestamps_by_filename(filename, df):
    row = df.loc[df['filename'] == filename].to_dict(orient='records')[0]
    result = []
    
    if not row["recap_start"] == -1:
        result.append((row["recap_start"], row["recap_end"]))
    if not row["openingcredits_start"] == -1:
        result.append((row["openingcredits_start"], row["openingcredits_end"]))
    if not row["preview_start"] == -1:
        result.append((row["preview_start"], row["preview_end"]))
    if not row["closingcredits_start"] == -1:
        result.append((row["closingcredits_start"], row["closingcredits_end"]))
        
    return merge_consecutive_timestamps(result)

annotations = pd.read_csv("annotations_legal_new_final.csv").dropna(how='all')
annotations['recap_start'] = annotations['recap_start'].apply(to_seconds)
annotations['recap_end'] = annotations['recap_end'].apply(to_seconds)
annotations['openingcredits_end'] = annotations['openingcredits_end'].apply(to_seconds)
annotations['openingcredits_start'] = annotations['openingcredits_start'].apply(to_seconds)
annotations['preview_start'] = annotations['preview_start'].apply(to_seconds)
annotations['preview_end'] = annotations['preview_end'].apply(to_seconds)
annotations['closingcredits_end'] = annotations['closingcredits_end'].apply(to_seconds)
annotations['closingcredits_start'] = annotations['closingcredits_start'].apply(to_seconds)

annotations.head()
# Out:
#                          filename  recap_start  recap_end  \
# 0  193757H1_Divorce_S1_E1.mxf.mp4           -1         -1
# 1  193916H1_Divorce_S1_E2.mxf.mp4            0         75
# 2  193917H1_Divorce_S1_E3.mxf.mp4            0         88
# 5  208887H1_Divorce_S2_E1.mxf.mp4            0        100
# 6  208888H1_Divorce_S2_E2.mxf.mp4            0         71
#
#    openingcredits_start  openingcredits_end  preview_start  preview_end  \
# 0                    82                 141           2473         2503
# 1                    98                 158           2561         2590
# 2                   111                 171             -1           -1
# 5                   115                 175           2508         2538
# 6                    84                 143           2737         2767
#
#    closingcredits_start  closingcredits_end Unnamed: 9
# 0                    -1                  -1        NaN
# 1                    -1                  -1        NaN
# 2                    -1                  -1        NaN
# 5                    -1                  -1        NaN
# 6                    -1                  -1        NaN

# %%
get_skippable_timestamps_by_filename("217394H1_Divorce_S3_E1.mxf.mp4", annotations)
# Out:
# [(0, 70), (99, 159), (2494, 2525)]

# %%
# vectors_dir = "./videos/full_histograms_binsize30_framejump3/"
# vectors_dir = "./videos_resized_w320/colortexturemoments_framejump3/"
# vectors_dir = "./videos_resized_w320/color_histogram_binsize180_framejump3/"
# vectors_dir = "./videos_resized_w320/color_histogram_binsize300_framejump3/"
vectors_dir = "./videos_resized_w224/cnn_vectors_framejump3/" #verander dir name

# %%
import math

def get_keyframes_filename(video_filename):
    splitted = video_filename.split('.')
    if splitted[-1] == "p":
        keyframe_filename = '.'.join(splitted[:-2]).split('/')[-1] + '-Scenes.csv'
    else:
        keyframe_filename = '.'.join(splitted[:-1]) + '-Scenes.csv'
    
    return 'keyframes/' + keyframe_filename

def get_keyframes(fn):
    result = []
    df = pd.read_csv(fn, encoding='utf-8', engine='python')
    try:
        result = df['Start Frame'].tolist()
    except:
        with open(fn, 'r') as fin:
            data = fin.read().splitlines(True)
        with open(fn, 'w') as fout:
            fout.writelines(data[1:])
        df = pd.read_csv(fn)
        result = df['Start Frame'].tolist()
    
    return result

video_dir = 'videos_resized_w320/'
video_files = [f for f in listdir(video_dir) if isfile(join(video_dir, f))]
keyframes = get_keyframes(video_dir + get_keyframes_filename('193757H1_Divorce_S1_E1.mxf.mp4.p'))
keyframes = [math.ceil(k / 3) for k in keyframes]

dir = vectors_dir

histograms = []
lengths = []

f = dir + '193757H1_Divorce_S1_E1.mxf.mp4.p'
h = np.array(pickle.load(open(f, "rb")), np.float32)
keyframes = get_keyframes(video_dir + get_keyframes_filename(f))
keyframes = [math.ceil(k / 3) for k in keyframes]
h = h[keyframes]
lengths.append(h.shape[0])
histograms.append(h)

print(histograms[0].shape)
histograms = np.vstack(histograms)
print(lengths)
histograms.shape
# Out:
# (550, 512)
# [550]
# (550, 512)

# %%
def do_faiss(episodes):
    print(episodes)
    dir = vectors_dir

    vector_files = [dir+e+'.p' for e in episodes]

    histograms = []
    lengths = []

    for f in vector_files:
        h = np.array(pickle.load(open(f, "rb")), np.float32)
        keyframes = get_keyframes(video_dir + get_keyframes_filename(f))
        keyframes = [math.ceil(k / 3) for k in keyframes]
        h = np.vstack([h, h[:-2]])
        h = h[keyframes]
        lengths.append(h.shape[0])
        histograms.append(h)

    print(histograms[0].shape)
    histograms = np.vstack(histograms)
    print(lengths)
    histograms.shape

    results = []
    for i, length in enumerate(lengths):
        i += 1
        s = sum(lengths[:i-1])
        e = sum(lengths[:i])
        print("q - {} : {}".format(s,e))
        print("rest - < {}".format(s))
        q = histograms[s:e]
        rest = np.append(histograms[:s], histograms[e:], axis=0)
    #     rest = histograms[:s]

        vector_size = q.shape[1]
        # build the index, set vector size
        print("Building index with size: {}".format(rest.shape[0]))
        index = faiss.IndexFlatL2(vector_size)    
        # add vectors to the index
        index.add(rest)

        # we want to see k nearest neighbors
        k = 1
        # search with for matches with q
        scores, indexes = index.search(q, k)

    #     print(scores)
    #     print(indexes)
        
        result = scores[:,0]
#         result = scipy.ndimage.median_filter(result, 10)
        
        keyframes = get_keyframes(video_dir + get_keyframes_filename(episodes[i-1]))
        keyframes = [math.ceil(k / 3) for k in keyframes]

        results.append((episodes[i-1], keyframes, result))
        
#         l = result.shape[0]
#         plt.figure()
#         plt.bar(range(0,l), result)
#         plt.ylim(0, 0.2)  
#         plt.show()
        
#         plt.figure()
#         s = pd.Series(result)
#         s.rolling(window=15).mean().plot()
#         plt.ylim(0, 0.2)
#         plt.show()
        
        print()
    print()
    print()
    print("=========================================================================================")
    return results

# %%
# put inside a function to be able to stop it with return
def run():
    results = []
    for serie, seizoenen in shows.items():
#         seizoenen = result['Judas']
        for seizoen, episodes in seizoenen.items():
            # bit hacky way to make sure episodes are sorted by E1, E2, .., E10
            keys = sorted([int(k.replace("E","")) for k in episodes.keys()])
            episodes = [episodes["E{}".format(k)] for k in keys]
            print(episodes)
            try:
                results = results + do_faiss(episodes)
                
            except KeyboardInterrupt:
                print("STOPPPPP!!!!!!!!")
                return results
                
    return results
    
results = run()
# Out:
# ['217394H1_Divorce_S3_E1.mxf.mp4', '217395H1_Divorce_S3_E2.mxf.mp4', '217396H1_Divorce_S3_E3.mxf.mp4']
# ['217394H1_Divorce_S3_E1.mxf.mp4', '217395H1_Divorce_S3_E2.mxf.mp4', '217396H1_Divorce_S3_E3.mxf.mp4']
# (523, 512)
# [523, 583, 584]
# q - 0 : 523
# rest - < 0
# Building index with size: 1167
#
# q - 523 : 1106
# rest - < 523
# Building index with size: 1107
#
# q - 1106 : 1690
# rest - < 1106
# Building index with size: 1106
#
#
#
# =========================================================================================
# ['208887H1_Divorce_S2_E1.mxf.mp4', '208888H1_Divorce_S2_E2.mxf.mp4', '208889H1_Divorce_S2_E3.mxf.mp4']
# ['208887H1_Divorce_S2_E1.mxf.mp4', '208888H1_Divorce_S2_E2.mxf.mp4', '208889H1_Divorce_S2_E3.mxf.mp4']
# (594, 512)
# [594, 565, 632]
# q - 0 : 594
# rest - < 0
# Building index with size: 1197
#
# q - 594 : 1159
# rest - < 594
# Building index with size: 1226
#
# q - 1159 : 1791
# rest - < 1159
# Building index with size: 1159
#
#
#
# =========================================================================================
# ['193757H1_Divorce_S1_E1.mxf.mp4', '193916H1_Divorce_S1_E2.mxf.mp4', '193917H1_Divorce_S1_E3.mxf.mp4']
# ['193757H1_Divorce_S1_E1.mxf.mp4', '193916H1_Divorce_S1_E2.mxf.mp4', '193917H1_Divorce_S1_E3.mxf.mp4']
# (550, 512)
# [550, 585, 604]
# q - 0 : 550
# rest - < 0
# Building index with size: 1189
#
# q - 550 : 1135
# rest - < 550
# Building index with size: 1154
#
# q - 1135 : 1739
# rest - < 1135
# Building index with size: 1135
#
#
#
# =========================================================================================
# ['226557H1_Expeditie_Robinson_S11_E1.mxf.mp4', '226558H1_Expeditie_Robinson_S11_E2.mxf.mp4', '226559H1_Expeditie_Robinson_S11_E3.mxf.mp4']
# ['226557H1_Expeditie_Robinson_S11_E1.mxf.mp4', '226558H1_Expeditie_Robinson_S11_E2.mxf.mp4', '226559H1_Expeditie_Robinson_S11_E3.mxf.mp4']
# (638, 512)
# [638, 1128, 1259]
# q - 0 : 638
# rest - < 0
# Building index with size: 2387
#
# q - 638 : 1766
# rest - < 638
# Building index with size: 1897
#
# q - 1766 : 3025
# rest - < 1766
# Building index with size: 1766
#
#
#
# =========================================================================================
# ['251218H1_Expeditie_Robinson_S13_E1.mxf.mp4', '250463H1_Expeditie_Robinson_S13_E2.mxf.mp4']
# ['251218H1_Expeditie_Robinson_S13_E1.mxf.mp4', '250463H1_Expeditie_Robinson_S13_E2.mxf.mp4']
# (1047, 512)
# [1047, 1256]
# q - 0 : 1047
# rest - < 0
# Building index with size: 1256
#
# q - 1047 : 2303
# rest - < 1047
# Building index with size: 1047
#
#
#
# =========================================================================================
# ['262135H1_Expeditie_Robinson_S14_E1.mxf.mp4', '262136H1_Expeditie_Robinson_S14_E2.mxf.mp4', '260888H1_Expeditie_Robinson_S14_E3.mxf.mp4']
# ['262135H1_Expeditie_Robinson_S14_E1.mxf.mp4', '262136H1_Expeditie_Robinson_S14_E2.mxf.mp4', '260888H1_Expeditie_Robinson_S14_E3.mxf.mp4']
# (1342, 512)
# [1342, 1085, 1267]
# q - 0 : 1342
# rest - < 0
# Building index with size: 2352
#
# q - 1342 : 2427
# rest - < 1342
# Building index with size: 2609
#
# q - 2427 : 3694
# rest - < 2427
# Building index with size: 2427
#
#
#
# =========================================================================================
# ['214579A1_Expeditie_Robinson_S10_E1.mxf.mp4', '214789B1_Expeditie_Robinson_S10_E2.mxf.mp4', '214790A1_Expeditie_Robinson_S10_E3.mxf.mp4']
# ['214579A1_Expeditie_Robinson_S10_E1.mxf.mp4', '214789B1_Expeditie_Robinson_S10_E2.mxf.mp4', '214790A1_Expeditie_Robinson_S10_E3.mxf.mp4']
# (837, 512)
# [837, 1157, 969]
# q - 0 : 837
# rest - < 0
# Building index with size: 2126
#
# q - 837 : 1994
# rest - < 837
# Building index with size: 1806
#
# q - 1994 : 2963
# rest - < 1994
# Building index with size: 1994
#
#
#
# =========================================================================================
# ['266841H1_Temptation_Island_S4_E1_high.mp4', '266843H1_Temptation_Island_S4_E2_high.mp4', '266844H1_Temptation_Island_S4_E3_high.mp4', '265707H1_Temptation_Island_S4_E4_high.mp4', '265708H1_Temptation_Island_S4_E5_high.mp4', '265709H1_Temptation_Island_S4_E6_high.mp4', '265710H1_Temptation_Island_S4_E7_high.mp4', '265711H1_Temptation_Island_S4_E8_high.mp4', '265712H1_Temptation_Island_S4_E9_high.mp4']
# ['266841H1_Temptation_Island_S4_E1_high.mp4', '266843H1_Temptation_Island_S4_E2_high.mp4', '266844H1_Temptation_Island_S4_E3_high.mp4', '265707H1_Temptation_Island_S4_E4_high.mp4', '265708H1_Temptation_Island_S4_E5_high.mp4', '265709H1_Temptation_Island_S4_E6_high.mp4', '265710H1_Temptation_Island_S4_E7_high.mp4', '265711H1_Temptation_Island_S4_E8_high.mp4', '265712H1_Temptation_Island_S4_E9_high.mp4']
# (1040, 512)
# [1040, 981, 941, 881, 730, 756, 835, 831, 720]
# q - 0 : 1040
# rest - < 0
# Building index with size: 6675
#
# q - 1040 : 2021
# rest - < 1040
# Building index with size: 6734
#
# q - 2021 : 2962
# rest - < 2021
# Building index with size: 6774
#
# q - 2962 : 3843
# rest - < 2962
# Building index with size: 6834
#
# q - 3843 : 4573
# rest - < 3843
# Building index with size: 6985
#
# q - 4573 : 5329
# rest - < 4573
# Building index with size: 6959
#
# q - 5329 : 6164
# rest - < 5329
# Building index with size: 6880
#
# q - 6164 : 6995
# rest - < 6164
# Building index with size: 6884
#
# q - 6995 : 7715
# rest - < 6995
# Building index with size: 6995
#
#
#
# =========================================================================================
# ['266537H1_How_Its_Done_S3_E1_high.mp4', '266184H1_How_Its_Done_S3_E2_high.mp4', '266185H1_How_Its_Done_S3_E3_high.mp4', '266186H1_How_Its_Done_S3_E4_high.mp4', '266187H1_How_Its_Done_S3_E5_high.mp4', '266188H1_How_Its_Done_S3_E6_high.mp4']
# ['266537H1_How_Its_Done_S3_E1_high.mp4', '266184H1_How_Its_Done_S3_E2_high.mp4', '266185H1_How_Its_Done_S3_E3_high.mp4', '266186H1_How_Its_Done_S3_E4_high.mp4', '266187H1_How_Its_Done_S3_E5_high.mp4', '266188H1_How_Its_Done_S3_E6_high.mp4']
# (342, 512)
# [342, 291, 302, 315, 300, 339]
# q - 0 : 342
# rest - < 0
# Building index with size: 1547
#
# q - 342 : 633
# rest - < 342
# Building index with size: 1598
#
# q - 633 : 935
# rest - < 633
# Building index with size: 1587
#
# q - 935 : 1250
# rest - < 935
# Building index with size: 1574
#
# q - 1250 : 1550
# rest - < 1250
# Building index with size: 1589
#
# q - 1550 : 1889
# rest - < 1550
# Building index with size: 1550
#
#
#
# =========================================================================================
# ['000_Dexter_S8_E1.mkv', '000_Dexter_S8_E2.mkv', '000_Dexter_S8_E3.mkv', '000_Dexter_S8_E4.mkv', '000_Dexter_S8_E5.mkv', '000_Dexter_S8_E6.mkv', '000_Dexter_S8_E7.mkv', '000_Dexter_S8_E8.mkv', '000_Dexter_S8_E9.mkv', '000_Dexter_S8_E10.mkv', '000_Dexter_S8_E11.mkv', '000_Dexter_S8_E12.mkv']
# ['000_Dexter_S8_E1.mkv', '000_Dexter_S8_E2.mkv', '000_Dexter_S8_E3.mkv', '000_Dexter_S8_E4.mkv', '000_Dexter_S8_E5.mkv', '000_Dexter_S8_E6.mkv', '000_Dexter_S8_E7.mkv', '000_Dexter_S8_E8.mkv', '000_Dexter_S8_E9.mkv', '000_Dexter_S8_E10.mkv', '000_Dexter_S8_E11.mkv', '000_Dexter_S8_E12.mkv']
# (990, 512)
# [990, 667, 890, 897, 642, 937, 848, 662, 800, 943, 571, 874]
# q - 0 : 990
# rest - < 0
# Building index with size: 8731
#
# q - 990 : 1657
# rest - < 990
# Building index with size: 9054
#
# q - 1657 : 2547
# rest - < 1657
# Building index with size: 8831
#
# q - 2547 : 3444
# rest - < 2547
# Building index with size: 8824
#
# q - 3444 : 4086
# rest - < 3444
# Building index with size: 9079
#
# q - 4086 : 5023
# rest - < 4086
# Building index with size: 8784
#
# q - 5023 : 5871
# rest - < 5023
# Building index with size: 8873
#
# q - 5871 : 6533
# rest - < 5871
# Building index with size: 9059
#
# q - 6533 : 7333
# rest - < 6533
# Building index with size: 8921
#
# q - 7333 : 8276
# rest - < 7333
# Building index with size: 8778
#
# q - 8276 : 8847
# rest - < 8276
# Building index with size: 9150
#
# q - 8847 : 9721
# rest - < 8847
# Building index with size: 8847
#
#
#
# =========================================================================================
# ['263777H1_Judas_S1_E1_high.mp4', '263778H1_Judas_S1_E2_high.mp4', '263779H1_Judas_S1_E3_high.mp4', '263780H1_Judas_S1_E4_high.mp4', '263781H1_Judas_S1_E5_high.mp4', '263782H1_Judas_S1_E6_high.mp4']
# ['263777H1_Judas_S1_E1_high.mp4', '263778H1_Judas_S1_E2_high.mp4', '263779H1_Judas_S1_E3_high.mp4', '263780H1_Judas_S1_E4_high.mp4', '263781H1_Judas_S1_E5_high.mp4', '263782H1_Judas_S1_E6_high.mp4']
# (781, 512)
# [781, 775, 831, 737, 679, 796]
# q - 0 : 781
# rest - < 0
# Building index with size: 3818
#
# q - 781 : 1556
# rest - < 781
# Building index with size: 3824
#
# q - 1556 : 2387
# rest - < 1556
# Building index with size: 3768
# q - 2387 : 3124
# rest - < 2387
# Building index with size: 3862
#
# q - 3124 : 3803
# rest - < 3124
# Building index with size: 3920
#
# q - 3803 : 4599
# rest - < 3803
# Building index with size: 3803
#
#
#
# =========================================================================================
# ['219119H1_Familie_Kruys_S1_E1_VOD.mxf.mp4', '219120H1_Familie_Kruys_S1_E2_VOD.mxf.mp4', '219121H1_Familie_Kruys_S1_E3_VOD.mxf.mp4']
# ['219119H1_Familie_Kruys_S1_E1_VOD.mxf.mp4', '219120H1_Familie_Kruys_S1_E2_VOD.mxf.mp4', '219121H1_Familie_Kruys_S1_E3_VOD.mxf.mp4']
# (727, 512)
# [727, 799, 724]
# q - 0 : 727
# rest - < 0
# Building index with size: 1523
#
# q - 727 : 1526
# rest - < 727
# Building index with size: 1451
#
# q - 1526 : 2250
# rest - < 1526
# Building index with size: 1526
#
#
#
# =========================================================================================
# ['261245H1_Familie_Kruys_S4_E1.mxf.mp4', '261246H1_Familie_Kruys_S4_E2.mxf.mp4', '261247H1_Familie_Kruys_S4_E3.mxf.mp4']
# ['261245H1_Familie_Kruys_S4_E1.mxf.mp4', '261246H1_Familie_Kruys_S4_E2.mxf.mp4', '261247H1_Familie_Kruys_S4_E3.mxf.mp4']
# (837, 512)
# [837, 891, 868]
# q - 0 : 837
# rest - < 0
# Building index with size: 1759
#
# q - 837 : 1728
# rest - < 837
# Building index with size: 1705
#
# q - 1728 : 2596
# rest - < 1728
# Building index with size: 1728
#
#
#
# =========================================================================================
# ['263269H1_Raveleijn_S1_E1_high.mp4', '263270H1_Raveleijn_S1_E2_high.mp4', '263271H1_Raveleijn_S1_E3_high.mp4', '263272H1_Raveleijn_S1_E4_high.mp4', '263273H1_Raveleijn_S1_E5_high.mp4', '263274H1_Raveleijn_S1_E6_high.mp4', '263275H1_Raveleijn_S1_E7_high.mp4', '263276H1_Raveleijn_S1_E8_high.mp4', '263277H1_Raveleijn_S1_E9_high.mp4', '263278H1_Raveleijn_S1_E10_high.mp4', '263279H1_Raveleijn_S1_E11_high.mp4', '263280H1_Raveleijn_S1_E12_high.mp4']
# ['263269H1_Raveleijn_S1_E1_high.mp4', '263270H1_Raveleijn_S1_E2_high.mp4', '263271H1_Raveleijn_S1_E3_high.mp4', '263272H1_Raveleijn_S1_E4_high.mp4', '263273H1_Raveleijn_S1_E5_high.mp4', '263274H1_Raveleijn_S1_E6_high.mp4', '263275H1_Raveleijn_S1_E7_high.mp4', '263276H1_Raveleijn_S1_E8_high.mp4', '263277H1_Raveleijn_S1_E9_high.mp4', '263278H1_Raveleijn_S1_E10_high.mp4', '263279H1_Raveleijn_S1_E11_high.mp4', '263280H1_Raveleijn_S1_E12_high.mp4']
# (324, 512)
# [324, 341, 356, 297, 384, 418, 409, 388, 337, 325, 422, 465]
# q - 0 : 324
# rest - < 0
# Building index with size: 4142
#
# q - 324 : 665
# rest - < 324
# Building index with size: 4125
#
# q - 665 : 1021
# rest - < 665
# Building index with size: 4110
#
# q - 1021 : 1318
# rest - < 1021
# Building index with size: 4169
#
# q - 1318 : 1702
# rest - < 1318
# Building index with size: 4082
#
# q - 1702 : 2120
# rest - < 1702
# Building index with size: 4048
#
# q - 2120 : 2529
# rest - < 2120
# Building index with size: 4057
#
# q - 2529 : 2917
# rest - < 2529
# Building index with size: 4078
#
# q - 2917 : 3254
# rest - < 2917
# Building index with size: 4129
#
# q - 3254 : 3579
# rest - < 3254
# Building index with size: 4141
#
# q - 3579 : 4001
# rest - < 3579
# Building index with size: 4044
#
# q - 4001 : 4466
# rest - < 4001
# Building index with size: 4001
#
#
#
# =========================================================================================
# ['258519H1_Het_Italiaanse_Dorp_S1_E1.mxf.mp4', '258520H1_Het_Italiaanse_Dorp_S1_E2.mxf.mp4']
# ['258519H1_Het_Italiaanse_Dorp_S1_E1.mxf.mp4', '258520H1_Het_Italiaanse_Dorp_S1_E2.mxf.mp4']
# (668, 512)
# [668, 720]
# q - 0 : 668
# rest - < 0
# Building index with size: 720
#
# q - 668 : 1388
# rest - < 668
# Building index with size: 668
#
#
#
# =========================================================================================
# ['245405H1_Meisje_Van_Plezier_S1_E1.mxf.mp4', '245406H1_Meisje_Van_Plezier_S1_E2.mxf.mp4', '245407H1_Meisje_Van_Plezier_S1_E3.mxf.mp4']
# ['245405H1_Meisje_Van_Plezier_S1_E1.mxf.mp4', '245406H1_Meisje_Van_Plezier_S1_E2.mxf.mp4', '245407H1_Meisje_Van_Plezier_S1_E3.mxf.mp4']
# (675, 512)
# [675, 671, 297]
# q - 0 : 675
# rest - < 0
# Building index with size: 968
#
# q - 675 : 1346
# rest - < 675
# Building index with size: 972
#
# q - 1346 : 1643
# rest - < 1346
# Building index with size: 1346
#
#
#
# =========================================================================================
# ['266160H1_Herman_Tegen_De_Rest_S1_E1_high.mp4', '266161H1_Herman_Tegen_De_Rest_S1_E2_high.mp4', '266162H1_Herman_Tegen_De_Rest_S1_E3_high.mp4', '266163H1_Herman_Tegen_De_Rest_S1_E4_high.mp4']
# ['266160H1_Herman_Tegen_De_Rest_S1_E1_high.mp4', '266161H1_Herman_Tegen_De_Rest_S1_E2_high.mp4', '266162H1_Herman_Tegen_De_Rest_S1_E3_high.mp4', '266163H1_Herman_Tegen_De_Rest_S1_E4_high.mp4']
# (712, 512)
# [712, 794, 768, 696]
# q - 0 : 712
# rest - < 0
# Building index with size: 2258
#
# q - 712 : 1506
# rest - < 712
# Building index with size: 2176
#
# q - 1506 : 2274
# rest - < 1506
# Building index with size: 2202
#
# q - 2274 : 2970
# rest - < 2274
# Building index with size: 2274
#
#
#
# =========================================================================================

# %%
def fill_gaps(sequence, lookahead):
    i = 0
    while i < len(sequence) - lookahead:
        current = sequence[i]
        next = sequence[i + 1 : i + lookahead].tolist()
        
        if current and True in next:
            x = 0
            while not next[x]:
                sequence[i + 1 + x] = True
                x = x + 1
                
        i = i + 1

    return sequence

def to_time_string(seconds):
    """
    Given seconds in number, returns a string in the format hh:mm:ss (example: 01:30:45)
    """
    return str(datetime.timedelta(seconds=seconds))

def sum_timestamps(timestamps):
    """
    Get the toal number of seconds out of a list with timestamps formatted like: (start,end)
    """
    result = 0
    for start,end in timestamps:
        result += end - start
        
    return result


def overlap(interval1, interval2):
    return max(0, min(interval1[1], interval2[1]) - max(interval1[0], interval2[0]))

# matches two lists of (starttime,endtime) detections and outputs cumulative gain
def match_detections_precision_recall(detected, ground_truth, verbose=False):
    
    if verbose:
        print("Comparing detections")
        print("detected: \t \t {}".format(detected))
        print("ground truth: \t \t {}".format(ground_truth))


    total_relevant_seconds = sum_timestamps(ground_truth)
    total_detected_seconds = sum_timestamps(detected)
    relevant_detected_seconds = 0    

    for start, end in ground_truth:
        lowest_difference_index = 0
        lowest_difference = -1        

        for i, (start_d, end_d) in enumerate(detected):
  
            if abs(start - start_d) < 2:
                start_d = start
            if abs(end - end_d) < 2:
                end_d = end

            relevant = overlap((start,end), (start_d, end_d))
            relevant_detected_seconds += relevant
    
    if verbose:
        print("total relevant seconds: {}".format(total_relevant_seconds)) #relevant documents
        print("total detected seconds: {}".format(total_detected_seconds)) #retrieved documents
        print("relevant detected seconds: {}".format(relevant_detected_seconds)) #relevant documents AND retrieved documents

        if total_detected_seconds > 0:
            print("Precision = {}".format(relevant_detected_seconds / total_detected_seconds))

        if total_relevant_seconds > 0:
            print("Recall = {}".format(relevant_detected_seconds / total_relevant_seconds))

    return total_relevant_seconds, total_detected_seconds, relevant_detected_seconds

# TESTS
# print("overlap: {}".format(overlap((0,20),(5,15))))

# # case 1
# d = [(92.75999999999999, 120.47999999999999), (154.67999999999998, 217.92)]
# gt =  [(154, 218)]
# match_detections_precision_recall(d, gt)

# print()

# # case 2
# d =  [(99.6, 159.0)]
# gt = [(0, 70), (99, 159)]
# match_detections_precision_recall(d, gt)

# print()

# # case 3
# d = [(92.75999999999999, 120.47999999999999), (154.67999999999998, 217.92), (300,400)]
# gt =  [(154, 218)]
# match_detections_precision_recall(d, gt)

# #case 4
# d = [(7.319999999999999, 134.88), (406.32, 423.47999999999996)]
# gt = [(0, 63), (75, 135)]
# match_detections_precision_recall(d, gt)

d= [(0.0, 48.79835917394137), (62.43687494306858, 203.57674455385285), (2942.791306184429, 3001.47446119104)]
gt = [(0, 198), (2945, 3006)]
match_detections_precision_recall(d, gt,True)


def max_two_values(d):
    """ a) create a list of the dict's keys and values; 
        b) return the key with the max value"""  
    v=list(d.values())
    k=list(d.keys())
    result1 = k[v.index(max(v))]
    del d[result1]

    v=list(d.values())
    k=list(d.keys())
    result2 = k[v.index(max(v))]
    return [result1, result2]

def get_two_longest_timestamps(timestamps):
    # if size is smaller or equal to 2, return immediately
    if len(timestamps) <= 2:
        return timestamps

    d = {}
    for start,end in timestamps:
        d[(start,end)] = end - start

    return max_two_values(d)

# TESTS
# timestamps = [(0.0, 63.12), (0,30), (84.36, 143.76), (476.28, 480), (490,510)]
# print(get_two_longest_timestamps(timestamps))
# Out:
# Comparing detections
# detected: 	 	 [(0.0, 48.79835917394137), (62.43687494306858, 203.57674455385285), (2942.791306184429, 3001.47446119104)]
# ground truth: 	 	 [(0, 198), (2945, 3006)]
# total relevant seconds: 259
# total detected seconds: 248.62138379133694
# relevant detected seconds: 240.83594542191287
# Precision = 0.9686855641670862
# Recall = 0.9298685151425208

# %%
def experiment(percentile, plot = False, verbose=False):
    
    framejump = 3
    
    total_error = 0
    total_ground_truth = 0

    cumulative_gain_gt = [0]
    cumulative_gain = [0]

    total_relevant_seconds = 0
    total_detected_seconds = 0
    total_relevant_detected_seconds = 0

    for fn, keyframes, result in results:
        if verbose:
            print(fn)
                
        framerate = 25
        if "Dexter" in fn:
            framerate = 23.976216
            
        threshold = np.percentile(result, percentile)
        seq = result
        result2 = result

        if plot:
            plt.figure()
            plt.plot(result2)
            plt.plot([threshold]*len(seq))
            plt.show()

        below_threshold2 = result2 < threshold
        below_threshold = fill_gaps(below_threshold2, 7) #fill gaps over 8 shots

        if plot:
            plt.plot(below_threshold)
            plt.show()

        nonzeros = [[i for i,value in it] for key, it in itertools.groupby(enumerate(below_threshold), key=operator.itemgetter(1)) if key != 0]

        detected_beginning = []
        detected_end = []

        for nonzero in nonzeros:
            try:
                start = keyframes[nonzero[0]]
                end = keyframes[nonzero[-1]]
            except:
                print(nonzero)
                print(keyframes[-5:])
                print(len(keyframes))
                raise

            occurs_at_beginning = end < keyframes[-1] / 5              #result is in first 20% of the video
            ends_at_the_end = end > keyframes[-1] - 15 * (framerate/framejump) #the end of this timestamp ends in the last 15 seconds

            if (end - start > (15 * (framerate / framejump)) #only count when larger than x seconds             
                and (occurs_at_beginning or ends_at_the_end)): #only use results that are in first 1/5 part or end at last 5s            

    #             print(to_time_string(start / (25 / framejump)))
    #             print(to_time_string(end / (25 / framejump)))

    #             print(start / (25 / framejump))
    #             print(end / (25 / framejump))
                start = start / (framerate / framejump)
                end = end / (framerate / framejump)

                if occurs_at_beginning:
                    detected_beginning.append((start,end))
                elif ends_at_the_end:
                    detected_end.append((start,end))


        detected = get_two_longest_timestamps(detected_beginning) + detected_end

        try:
            # get list of ground truth timestamps [(start,end), (start,end)]
            ground_truths = get_skippable_timestamps_by_filename(fn, annotations)
            # total seconds of ground truth within this video
    #         ground_truths_sum = sum_timestamps(ground_truths)
    #         total_ground_truth += ground_truths_sum
            relevant_seconds, detected_seconds, relevant_detected_seconds = match_detections_precision_recall(detected, ground_truths, verbose)

            total_relevant_seconds += relevant_seconds
            total_detected_seconds += detected_seconds
            total_relevant_detected_seconds += relevant_detected_seconds

    #         print("Precision = {}".format(relevant_detected_seconds / detected_seconds))
    #         print("Recall = {}".format(relevant_detected_seconds / relevant_seconds))


    #         mismatch_seconds = match_detections(detected.copy(), ground_truths.copy())        
    #         total_error += mismatch_seconds        

    #         cumulative_gain_gt.append(total_ground_truth)
    #         cumulative_gain.append(cumulative_gain[-1] + match_detections_cumulativegain(detected, ground_truths))
        except:
            traceback.print_exc()
            print("Error!!!")

        if verbose:
            print("=========================================================================================")

    # print("Total error of:\t {} seconds".format(total_error))
    # print("Total error of:\t {} minutes".format(total_error/60))
    # print()
    # print("Total ground truth:\t {} s".format(total_ground_truth))
    # print("Accuracy ratio:\t {}".format(total_ground_truth / (total_ground_truth + total_error)))

    # plt.plot(cumulative_gain, label = 'detected')
    # plt.plot(cumulative_gain_gt, label = 'ground_truth')
    # plt.legend(loc='upper left')
    # plt.show()

    # print("Ratio cumulative gain: {}".format(cumulative_gain[-1] / cumulative_gain_gt[-1]))
    precision = total_relevant_detected_seconds / total_detected_seconds
    recall = total_relevant_detected_seconds / total_relevant_seconds

    print("Total precision = {0:.3f}".format(precision))
    print("Total recall = {0:.3f}".format(recall))

#     print("F1 = {0:.3f}".format((2*precision*recall) / (precision+recall)))

print("Computing with feature vectors: {}".format(vectors_dir))
for p in [5, 7.5, 10]:
    print("Results percentile={}".format(p))
#     experiment(p, plot=True, verbose=True)
    experiment(p, False, False)
    print()
    print("----------------------------------------------------------------------------------------------------")
# Out:
# Computing with feature vectors: ./videos_resized_w224/cnn_vectors_framejump3/
# Results percentile=5
# Total precision = 0.837
# Total recall = 0.522
#
# ----------------------------------------------------------------------------------------------------
# Results percentile=7.5
# Total precision = 0.800
# Total recall = 0.635
#
# ----------------------------------------------------------------------------------------------------
# Results percentile=10
# Total precision = 0.725
# Total recall = 0.713
#
# ----------------------------------------------------------------------------------------------------

# %%
for fn, keyframes, r in results:
    print("{} - {}".format(fn,len(keyframes)))
# Out:
# 217394H1_Divorce_S3_E1.mxf.mp4 - 523
# 217395H1_Divorce_S3_E2.mxf.mp4 - 583
# 217396H1_Divorce_S3_E3.mxf.mp4 - 584
# 208887H1_Divorce_S2_E1.mxf.mp4 - 594
# 208888H1_Divorce_S2_E2.mxf.mp4 - 565
# 208889H1_Divorce_S2_E3.mxf.mp4 - 632
# 193757H1_Divorce_S1_E1.mxf.mp4 - 550
# 193916H1_Divorce_S1_E2.mxf.mp4 - 585
# 193917H1_Divorce_S1_E3.mxf.mp4 - 604
# 226557H1_Expeditie_Robinson_S11_E1.mxf.mp4 - 638
# 226558H1_Expeditie_Robinson_S11_E2.mxf.mp4 - 1128
# 226559H1_Expeditie_Robinson_S11_E3.mxf.mp4 - 1259
# 251218H1_Expeditie_Robinson_S13_E1.mxf.mp4 - 1047
# 250463H1_Expeditie_Robinson_S13_E2.mxf.mp4 - 1256
# 262135H1_Expeditie_Robinson_S14_E1.mxf.mp4 - 1342
# 262136H1_Expeditie_Robinson_S14_E2.mxf.mp4 - 1085
# 260888H1_Expeditie_Robinson_S14_E3.mxf.mp4 - 1267
# 214579A1_Expeditie_Robinson_S10_E1.mxf.mp4 - 837
# 214789B1_Expeditie_Robinson_S10_E2.mxf.mp4 - 1157
# 214790A1_Expeditie_Robinson_S10_E3.mxf.mp4 - 969
# 266841H1_Temptation_Island_S4_E1_high.mp4 - 1040
# 266843H1_Temptation_Island_S4_E2_high.mp4 - 981
# 266844H1_Temptation_Island_S4_E3_high.mp4 - 941
# 265707H1_Temptation_Island_S4_E4_high.mp4 - 881
# 265708H1_Temptation_Island_S4_E5_high.mp4 - 730
# 265709H1_Temptation_Island_S4_E6_high.mp4 - 756
# 265710H1_Temptation_Island_S4_E7_high.mp4 - 835
# 265711H1_Temptation_Island_S4_E8_high.mp4 - 831
# 265712H1_Temptation_Island_S4_E9_high.mp4 - 720
# 266537H1_How_Its_Done_S3_E1_high.mp4 - 342
# 266184H1_How_Its_Done_S3_E2_high.mp4 - 291
# 266185H1_How_Its_Done_S3_E3_high.mp4 - 302
# 266186H1_How_Its_Done_S3_E4_high.mp4 - 315
# 266187H1_How_Its_Done_S3_E5_high.mp4 - 300
# 266188H1_How_Its_Done_S3_E6_high.mp4 - 339
# 000_Dexter_S8_E1.mkv - 990
# 000_Dexter_S8_E2.mkv - 667
# 000_Dexter_S8_E3.mkv - 890
# 000_Dexter_S8_E4.mkv - 897
# 000_Dexter_S8_E5.mkv - 642
# 000_Dexter_S8_E6.mkv - 937
# 000_Dexter_S8_E7.mkv - 848
# 000_Dexter_S8_E8.mkv - 662
# 000_Dexter_S8_E9.mkv - 800
# 000_Dexter_S8_E10.mkv - 943
# 000_Dexter_S8_E11.mkv - 571
# 000_Dexter_S8_E12.mkv - 874
# 263777H1_Judas_S1_E1_high.mp4 - 781
# 263778H1_Judas_S1_E2_high.mp4 - 775
# 263779H1_Judas_S1_E3_high.mp4 - 831
# 263780H1_Judas_S1_E4_high.mp4 - 737
# 263781H1_Judas_S1_E5_high.mp4 - 679
# 263782H1_Judas_S1_E6_high.mp4 - 796
# 219119H1_Familie_Kruys_S1_E1_VOD.mxf.mp4 - 727
# 219120H1_Familie_Kruys_S1_E2_VOD.mxf.mp4 - 799
# 219121H1_Familie_Kruys_S1_E3_VOD.mxf.mp4 - 724
# 261245H1_Familie_Kruys_S4_E1.mxf.mp4 - 837
# 261246H1_Familie_Kruys_S4_E2.mxf.mp4 - 891
# 261247H1_Familie_Kruys_S4_E3.mxf.mp4 - 868
# 263269H1_Raveleijn_S1_E1_high.mp4 - 324
# 263270H1_Raveleijn_S1_E2_high.mp4 - 341
# 263271H1_Raveleijn_S1_E3_high.mp4 - 356
# 263272H1_Raveleijn_S1_E4_high.mp4 - 297
# 263273H1_Raveleijn_S1_E5_high.mp4 - 384
# 263274H1_Raveleijn_S1_E6_high.mp4 - 418
# 263275H1_Raveleijn_S1_E7_high.mp4 - 409
# 263276H1_Raveleijn_S1_E8_high.mp4 - 388
# 263277H1_Raveleijn_S1_E9_high.mp4 - 337
# 263278H1_Raveleijn_S1_E10_high.mp4 - 325
# 263279H1_Raveleijn_S1_E11_high.mp4 - 422
# 263280H1_Raveleijn_S1_E12_high.mp4 - 465
# 258519H1_Het_Italiaanse_Dorp_S1_E1.mxf.mp4 - 668
# 258520H1_Het_Italiaanse_Dorp_S1_E2.mxf.mp4 - 720
# 245405H1_Meisje_Van_Plezier_S1_E1.mxf.mp4 - 675
# 245406H1_Meisje_Van_Plezier_S1_E2.mxf.mp4 - 671
# 245407H1_Meisje_Van_Plezier_S1_E3.mxf.mp4 - 297
# 266160H1_Herman_Tegen_De_Rest_S1_E1_high.mp4 - 712
# 266161H1_Herman_Tegen_De_Rest_S1_E2_high.mp4 - 794
# 266162H1_Herman_Tegen_De_Rest_S1_E3_high.mp4 - 768
# 266163H1_Herman_Tegen_De_Rest_S1_E4_high.mp4 - 696
